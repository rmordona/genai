# %%
from graphviz import Digraph
from IPython.display import display, SVG

def display_graph():
    graph = Digraph('G', filename='graph.gv', format='svg', engine='dot')
    graph.node('A', 'Node A')
    graph.node('B', 'Node Bx')
    graph.edge('A', 'B')
    return graph

# Create the graph
graph = display_graph()

# Render the graph and display it in the notebook
display(SVG(graph.pipe().decode()))

# %%
from graphviz import Source
dot_graph = """
digraph G {
    node [shape=circle];
    // rankdir=LR; // Set the layout direction to left-to-right

    A -> B;
    B -> C;
    C -> A;
    
    // Record-type nodes with associated attributes 
    A_label [shape=record, label="{Row 1, Col 1|1|Row 2, Col 1|Row 3, Col 1}|{Row 1, Col 2|Row 2, Col 2|Row 3, Col2}"];
    B_label [shape=record, label="{Operations|Attribute 1: value3|Attribute 2: value4}"];
    C_label [shape=record, label="{Operations|Attribute 1: value5|Attribute 2: value6}"];
 
    
    // Connections between nodes and corresponding record-type nodes
    Node_A -> A_label;
    Node_B -> B_label;
    Node_C -> C_label;
}
"""

# Create a Source object from the DOT format graph
source = Source(dot_graph, format='svg')

# Display the graph in the notebook
display(source)

# %%
import genai as ai

scraper = ai.Scraper();
# Out:
# Current Directory: /Users/raymondordona/Workspace/genaiproj/notebook

# %%
class MyTokenModel(ai.BPETokenizer):

   def __init__(self):
     super().__init__();


tokenizer = ai.BPETokenizer();

# %%
class MyModel(ai.BaseModel):

   def __init__(self):
     super().__init__();

     print("Creating a Graph!")
     graph = ai.Graph();

     print("Add Node 1 ...")
     embedding1 = [[1.0, 2.0, 3.0, 4.0], [3.0, 4.0, 5.0, 6.0]]
     node1 = graph.addNode("Node 1", ai.NodeType.Input, embedding1)
     node1.setOperations([ai.Encoder(heads=2, size=3, bias=True, type="leakyrelu", alpha=0.01)]);
     #node1.setOperations([ai.FeedForward(size=2, bias=True, type="leakyrelu", alpha=0.01)]);
     #node1.setOperations([ai.Attention(heads=1, size=2, bias=False), ai.Activation(type="leakyrelu", alpha=0.01)]);
     #node1.setOperations([ai.Linear(size=2, bias=True), ai.BatchNorm(), ai.Activation(type="leakyrelu", alpha=0.01)]);
     #node1.setOperations([ai.Linear(size=2, bias=True)]);

     print("Add Node 3 ...")
     node3 = graph.addNode("Node 3", ai.NodeType.Output)
     #node3.setOperations([ai.Linear(size=3, bias=True), ai.LayerNorm(), ai.Activation(type="leakyrelu", alpha=0.01)]) 
     node3.setOperations([ai.Linear(size=3, bias=True), ai.Activation(type="leakyrelu", alpha=0.01)]) 
     #node3.setOperations([ai.Linear(size=3, bias=True)]) 
     # embedding = [[1.0, 2.0, 3.0], [3.0, 4.0, 6.0]]
     # graph.setData(embedding);

     # assign to the instance
     self.graph = graph;
     self.node1 = node1
     self.node3 = node3

     print("Connect nodes ...");
     self.graph.connect(self.node1, self.node3);

     self.setGraph(self.graph);

model = MyModel();
# Out:
# Creating a Graph!
# Add Node 1 ...
# Add Node 3 ...
# Connect nodes ...

# %%
target = [[1.0, 2.0, 3.0], [3.0, 4.0, 5.0]];
model.setTarget(target);
model.train(loss="mse", optimizer="adam", learnrate=0.01, iter=20);
# Out:
# Starting Iteration ...
# -------> Compute Loss:5.0007 ... elapsed 0.001005 at Sun Jul 30 21:04:28 2023
#
# -------> Compute Loss:5.00053 ... elapsed 0.000485 at Sun Jul 30 21:04:28 2023
#
# -------> Compute Loss:4.99939 ... elapsed 0.000455 at Sun Jul 30 21:04:28 2023
#
# -------> Compute Loss:4.99717 ... elapsed 0.000553 at Sun Jul 30 21:04:28 2023
#
# -------> Compute Loss:4.99274 ... elapsed 0.000461 at Sun Jul 30 21:04:28 2023
#
# -------> Compute Loss:4.98675 ... elapsed 0.000457 at Sun Jul 30 21:04:28 2023
#
# -------> Compute Loss:4.95935 ... elapsed 0.000455 at Sun Jul 30 21:04:28 2023
#
# -------> Compute Loss:4.93485 ... elapsed 0.000463 at Sun Jul 30 21:04:28 2023
#
# -------> Compute Loss:4.90375 ... elapsed 0.000626 at Sun Jul 30 21:04:28 2023
#
# -------> Compute Loss:4.86639 ... elapsed 0.000468 at Sun Jul 30 21:04:28 2023
#
# -------> Compute Loss:4.82331 ... elapsed 0.001001 at Sun Jul 30 21:04:28 2023
#
# -------> Compute Loss:4.77491 ... elapsed 0.00082 at Sun Jul 30 21:04:28 2023
#
# -------> Compute Loss:4.72147 ... elapsed 0.000523 at Sun Jul 30 21:04:28 2023
#
# -------> Compute Loss:4.66318 ... elapsed 0.000658 at Sun Jul 30 21:04:28 2023
#
# -------> Compute Loss:4.60019 ... elapsed 0.000613 at Sun Jul 30 21:04:28 2023
#
# -------> Compute Loss:4.53259 ... elapsed 0.000576 at Sun Jul 30 21:04:28 2023
#
# -------> Compute Loss:4.46047 ... elapsed 0.000518 at Sun Jul 30 21:04:28 2023
#
# -------> Compute Loss:4.38392 ... elapsed 0.000564 at Sun Jul 30 21:04:28 2023
#
# -------> Compute Loss:4.30301 ... elapsed 0.000571 at Sun Jul 30 21:04:28 2023
#
# -------> Compute Loss:4.21783 ... elapsed 0.000782 at Sun Jul 30 21:04:28 2023

# %%
mydot = model.graph.generateDotFormat()
mydot
# Out:
# 'digraph G {  node [shape=circle]; rankdir=LR; Node1; Node3; Node1->Node3;Node_1_label [shape=record, label="{* FeedForward *}|{* Linear Transformation (L1) *}|{Weights|min=-0.900768|max=0.258882}|{Biases|min=-0.199360|max=-0.194700}|{* Activation (leakyrelu)*}|{dInput|min=0.009210|max=0.033149}|{* Linear Transformation (L2) *}|{Weights|min=-1.070026|max=1.069850}|{Biases|min=-0.199386|max=0.212337}"]; Node_1->Node_1_label;Node_3_label [shape=record, label="{* Linear Transformation (generic) *}|{Weights|min=-0.844415|max=0.790522}|{Biases|min=0.200683|max=0.209220}|{* Activation (leakyrelu)*}|{dInput|min=-9.381850|max=-1.575358}"]; Node_3->Node_3_label;}'

# %%
from graphviz import Source

# Create a Source object from the DOT format graph
source = Source(mydot, format='svg')

# Display the graph in the notebook
display(source)
